# %%
import pandas as pd

james_bond_data = pd.read_csv("jamesbond.csv").convert_dtypes()#uploading the data 
james_bond_data
# Out:
#     Year                            Movie            Bond            Director  \
# 0   1962                           Dr. No    Sean Connery       Terence Young
# 1   1963            From Russia with Love    Sean Connery       Terence Young
# 2   1964                       Goldfinger    Sean Connery        Guy Hamilton
# 3   1965                      Thunderball    Sean Connery       Terence Young
# 4   1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 5   1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 6   1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 7   1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 8   1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 9   1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# 10  1979                        Moonraker     Roger Moore       Lewis Gilbert
# ...

# %%
james_bond_data.head()#returns first 5 rows
# Out:
#    Year                  Movie          Bond       Director      Composer  \
# 0  1962                 Dr. No  Sean Connery  Terence Young  Monty Norman
# 1  1963  From Russia with Love  Sean Connery  Terence Young    John Barry
# 2  1964             Goldfinger  Sean Connery   Guy Hamilton    John Barry
# 3  1965            Thunderball  Sean Connery  Terence Young    John Barry
# 4  1967    You Only Live Twice  Sean Connery  Lewis Gilbert    John Barry
#
#                                               Writer Cinematographer  \
# 0  Richard Maibaum, Johanna Harwood & Berkely Mather       Ted Moore
# 1                  Richard Maibaum & Johanna Harwood       Ted Moore
# 2                        Richard Maibaum & Paul Dehn       Ted Moore
# 3                     Richard Maibaum & John Hopkins       Ted Moore
# 4                                         Roald Dahl   Freddie Young
#
#                                    Depicted_Film_Loc  \
# ...

# %%
james_bond_data.tail()#returns last 5 rows
# Out:
#     Year              Movie            Bond         Director       Composer  \
# 19  2002    Die Another Day  Pierce Brosnan     Lee Tamahori   David Arnold
# 20  2006      Casino Royale    Daniel Craig  Martin Campbell   David Arnold
# 21  2008  Quantum of Solace    Daniel Craig     Marc Forster   David Arnold
# 22  2012            Skyfall    Daniel Craig       Sam Mendes  Thomas Newman
# 23  2015            Spectre    Daniel Craig       Sam Mendes  Thomas Newman
#
#                                                Writer    Cinematographer  \
# 19                        Neal Purvis and Robert Wade   David Tattersall
# 20             Neal Purvis, Robert Wade & Paul Haggis        Phil Méheux
# 21        Paul Haggis and Neal Purvis and Robert Wade   Roberto Schaefer
# 22              Neal Purvis, Robert Wade & John Logan      Roger Deakins
# 23  John Logan & Neal Purvis, Robert Wade & Jez Bu...  Hoyte van Hoytema
#
#                                     Depicted_Film_Loc  \
# ...

# %%
james_bond_data.info()# returns column names with null value count an datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               24 non-null     Int64
#  1   Movie              24 non-null     string
#  2   Bond               24 non-null     string
#  3   Director           24 non-null     string
#  4   Composer           24 non-null     string
#  5   Writer             24 non-null     string
#  6   Cinematographer    24 non-null     string
#  7   Depicted_Film_Loc  24 non-null     string
#  8   Shooting_Loc       24 non-null     string
#  9   Bond_Car_MFG       24 non-null     string
#  10  Bond_Girl_Nat      24 non-null     string
#  11  US_Gross           24 non-null     Int64
#  12  US_Adj             24 non-null     Int64
#  13  World_Gross        24 non-null     Int64
#  14  World_Adj          24 non-null     Int64
#  15  Budget             24 non-null     Int64
# ...

# %%
james_bond_data.describe()#gives statical analysis of dataset
# Out:
#               Year         US_Gross         US_Adj       World_Gross  \
# count         24.0             24.0           24.0              24.0
# mean   1984.291667     85767579.375  197093.958333  288246172.291667
# std      16.617118  71163545.469487   91824.547367  265710559.841648
# min         1962.0       16067035.0        64907.0        59567035.0
# 25%         1970.5       41175000.0       143166.5       122675000.0
# 50%         1982.0       52992500.0       181943.5       186450000.0
# 75%         1997.5      125710872.0      211977.75      357755120.75
# max         2015.0      304360277.0       468754.0      1108561108.0
#
#            World_Adj        Budget    Budget_Adj  Film_Length  Avg_User_IMDB  \
# count           24.0          24.0          24.0         24.0           24.0
# mean      626452.875  62091.666667      95128.25   126.833333       6.858333
# std    216136.222036  75828.564749  70676.679002    10.961064       0.517449
# ...

# %%
new_column_names = {
    "Release": "release_date",
    "Movie": "movie_title",
    "Bond": "bond_actor",
    "Bond_Car_MFG": "car_manufacturer",
    "US_Gross": "income_usa",
    "World_Gross": "income_world",
    "Budget ($ 000s)": "movie_budget",
    "Film_Length": "film_length",
    "Avg_User_IMDB": "imdb",
    "Avg_User_Rtn_Tom": "rotten_tomatoes",
    "Martinis": "martinis_consumed",
    "Kills_Bond": "bond_kills",
}

# data = james_bond_data.rename(columns=new_column_names)
# When you extract data from some systems, the column names may not be as meaningful 
# as you’d like. It’s good practice to make sure the columns in your DataFrame are sensibly named.

# %%
james_bond_data.columns#returns columns of data
# Out:
# Index(['Year', 'Movie', 'Bond', 'Director', 'Composer', 'Writer',
#        'Cinematographer', 'Depicted_Film_Loc', 'Shooting_Loc', 'Bond_Car_MFG',
#        'Bond_Girl_Nat', 'US_Gross', 'US_Adj', 'World_Gross', 'World_Adj',
#        'Budget', 'Budget_Adj', 'Film_Length', 'Avg_User_IMDB',
#        'Avg_User_Rtn_Tom', 'Conquests', 'Martinis', 'BJB', 'Kills_Bond',
#        'Kills_Others', 'Top_100', 'Video_Game'],
#       dtype='object')

# %%
james_bond_data.loc[james_bond_data.isna().any(axis="columns")]#selecting rows on the basis of
# Out:
# Empty DataFrame
# Columns: [Year, Movie, Bond, Director, Composer, Writer, Cinematographer, Depicted_Film_Loc, Shooting_Loc, Bond_Car_MFG, Bond_Girl_Nat, US_Gross, US_Adj, World_Gross, World_Adj, Budget, Budget_Adj, Film_Length, Avg_User_IMDB, Avg_User_Rtn_Tom, Conquests, Martinis, BJB, Kills_Bond, Kills_Others, Top_100, Video_Game]
# Index: []
#
# [0 rows x 27 columns]

# %%
pd.DataFrame({"imdb": {10: 7.1}, "rotten_tomatoes": {10: 6.8}})#make new row with index 10
# Out:
#     imdb  rotten_tomatoes
# 10   7.1              6.8

# %%
james_bond_data[
    ['Cinematographer', 'Depicted_Film_Loc', 'Shooting_Loc']
].head()
#give 1st 5 rows of selected variable only
# Out:
#   Cinematographer                                  Depicted_Film_Loc  \
# 0       Ted Moore                              Great Britain, Jamaic
# 1       Ted Moore  United Kingdom, Great Britain, Turkey, Croatia...
# 2       Ted Moore          United States, Great Britain, Switzerland
# 3       Ted Moore      France, Great Britain, Bahamas, United States
# 4   Freddie Young   United States, Russia, Kazakhstan, Norway, Japan
#
#                                     Shooting_Loc
# 0                               England, Jamaica
# 1  England, Scotland, Italy, Switzerland, Turkey
# 2            England, Switzerland, United States
# 3        England, France, Bahamas, United States
# 4                           Japan, Spain, Norway

# %%
james_bond_data["Bond"].value_counts()#counts the values of specific variables
# Out:
# Roger Moore       7
# Sean Connery      6
# Pierce Brosnan    4
# Daniel Craig      4
# Timothy Dalton    2
# George Lazenby    1
# Name: Bond, dtype: Int64

# %%
james_bond_data[["Film_Length", "Martinis"]].describe()#selected data statistical analysis
# Out:
#        Film_Length  Martinis
# count         24.0      24.0
# mean    126.833333  1.083333
# std      10.961064  1.316011
# min          106.0       0.0
# 25%         119.75       0.0
# 50%          127.5       1.0
# 75%          131.5       1.0
# max          148.0       6.0

# %%
data.loc[data.duplicated(keep=False)]#hide duplicates
# Out:
# Empty DataFrame
# Columns: [BJB, Bond_Girl_Nat, Budget, Budget_Adj, Cinematographer, Composer, Conquests, Depicted_Film_Loc, Director, Kills_Others, Shooting_Loc, Top_100, US_Adj, Video_Game, World_Adj, Writer, Year, bond_actor, bond_kills, car_manufacturer, film_length, imdb, income_usa, income_world, martinis_consumed, movie_title, rotten_tomatoes]
# Index: []
#
# [0 rows x 27 columns]

# %%
data = (
    james_bond_data.rename(columns=new_column_names)
    .combine_first(
        pd.DataFrame({"imdb": {10: 7.1}, "rotten_tomatoes": {10: 6.8}})
    )
    .assign(
        income_usa=lambda data: (
            data["income_usa"]
            .replace("[$,]", "", regex=True)#remove $ symbol
            .astype("Float64")
        ),
    )
)
james_bond_data
# Out:
#     Year                            Movie            Bond            Director  \
# 0   1962                           Dr. No    Sean Connery       Terence Young
# 1   1963            From Russia with Love    Sean Connery       Terence Young
# 2   1964                       Goldfinger    Sean Connery        Guy Hamilton
# 3   1965                      Thunderball    Sean Connery       Terence Young
# 4   1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 5   1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 6   1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 7   1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 8   1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 9   1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# 10  1979                        Moonraker     Roger Moore       Lewis Gilbert
# ...

# %%
data["bond_actor"].value_counts()
# Out:
# Roger Moore       7
# Sean Connery      6
# Pierce Brosnan    4
# Daniel Craig      4
# Timothy Dalton    2
# George Lazenby    1
# Name: bond_actor, dtype: Int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

james_bond_data = pd.read_csv("jamesbond.csv").convert_dtypes()

# %%
from sklearn.linear_model import LinearRegression

x = data.loc[:, ["imdb"]]
y = data.loc[:, "rotten_tomatoes"]

# %%
import matplotlib.pyplot as plt

# Create a scatter plot
fig, ax = plt.subplots()
ax.scatter(data["imdb"], data["rotten_tomatoes"], color="blue", alpha=0.7)

# Add labels and title
ax.set_title("Scatter Plot of Ratings")
ax.set_xlabel("Average IMDb Rating")
ax.set_ylabel("Average Rotten Tomatoes Rating")

# Show the plot
plt.show()

# %%
In [6]: fig, ax = plt.subplots()
   ...: length = data["film_length"].value_counts(bins=7).sort_index()
   ...: length.plot.bar(
   ...:     ax=ax,
   ...:     title="Film Length Distribution",
   ...:     xlabel="Time Range (mins)",
   ...:     ylabel="Count",
   ...: )
   ...: fig.show()#Bargraph for presenting the film length distribution
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3992\3000365721.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
data["film_length"].agg(["min", "max", "mean", "std"])#specific columns aggregate function calculations
# Out:
# min     106.000000
# max     148.000000
# mean    126.833333
# std      10.961064
# Name: film_length, dtype: float64

# %%
fig, ax = plt.subplots()
ax.scatter(data["imdb"], data["bond_kills"])
ax.set_title("Scatter Plot of Kills vs Ratings")
ax.set_xlabel("Average IMDb Rating")
ax.set_ylabel("Kills by Bond")
fig.show()# plotting a scatter plot for kills by bond
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3992\2569888516.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
plt.hist("Film_Length")
plt.show()
